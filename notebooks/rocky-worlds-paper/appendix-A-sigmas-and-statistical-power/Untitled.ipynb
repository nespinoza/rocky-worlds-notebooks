# %%
import os

# %% [markdown]
# [Top of Page](#top)
# <img style="float: right;" src="https://raw.githubusercontent.com/spacetelescope/roman_notebooks/7f391657bc2bf47a784400d65d2882703787416d/stsci_logo2.png" alt="Space Telescope Logo" width="200px"/>

# %% [markdown]
# [Top of Page](#top)
# <img style="float: right;"
#      src="../../../../stsci_logo2.png"
#      alt="Space Telescope Logo"
#      width="200px"/>

# %% [markdown]
# [Top of Page](#top)
# <img style="float: right;"
#      src="/files/../../../../stsci_logo2.png"
#      alt="Space Telescope Logo"
#      width="200px"/>

# %%
os.getcwd()
# Out:
# '/Users/nespinoza/github/rocky-worlds-notebooks/notebooks/rocky-worlds-paper/appendix-C-sigmas-and-statistical-power'

# %%
os.path.exists("../../../stsci_logo2.png")
# Out:
# True

# %%
# !ls ../../../
# Out:
# _config.yml     _toc.yml        intro.md        notebooks       stsci_logo2.png
# _static         conf.py         logo.png        README.md

# %%
from pathlib import Path

for p in Path(".").resolve().parents:
    candidate = p / "stsci_logo2.png"
    if candidate.exists():
        print("Found it at:", candidate)
# Out:
# Found it at: /Users/nespinoza/github/rocky-worlds-notebooks/stsci_logo2.png
